# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-text-mining/resources/d9pwm) course resource._
#
# ---

# %% [markdown]
# # Assignment 2 - Introduction to NLTK
#
# In part 1 of this assignment you will use nltk to explore the Herman Melville novel Moby Dick. Then in part 2 you will create a spelling recommender function that uses nltk to find words similar to the misspelling.

# %% [markdown]
# ## Part 1 - Analyzing Moby Dick

# %%
import nltk
import pandas as pd
import numpy as np
from nltk import FreqDist

# If you would like to work with the raw text you can use 'moby_raw'
with open('moby.txt', 'r') as f:
    moby_raw = f.read()
    
# If you would like to work with the novel in nltk.Text format you can use 'text1'
moby_tokens = nltk.word_tokenize(moby_raw)
text1 = nltk.Text(moby_tokens)

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
#moby_raw

# %%
#moby_tokens

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# ### Example 1
#
# How many tokens (words and punctuation symbols) are in text1?
#
# *This function should return an integer.*

# %%
def example_one():
    
    return len(nltk.word_tokenize(moby_raw)) # or alternatively len(text1)

example_one()
# Out:
# 255028

# %% [markdown]
# ### Example 2
#
# How many unique tokens (unique words and punctuation) does text1 have?
#
# *This function should return an integer.*

# %%
def example_two():
    
    return len(set(nltk.word_tokenize(moby_raw))) # or alternatively len(set(text1))

example_two()
# Out:
# 20742

# %%
res = list(set(nltk.word_tokenize(moby_raw)))

# %%
#res

# %% [markdown]
# ### Example 3
#
# After lemmatizing the verbs, how many unique tokens does text1 have?
#
# *This function should return an integer.*

# %%
from nltk.stem import WordNetLemmatizer

def example_three():

    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in text1]

    return lemmatized

example_three()
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'be',
#  'ever',
#  'dust',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellish',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flag',
#  'of',
#  'all',
#  'the',
#  'know',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'love',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'remind',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
#  'While',
# ...

# %% [markdown]
# ### Question 1
#
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)
#
# *This function should return a float.*

# %%
def answer_one():
    
    return example_two()/example_one()

answer_one()
# Out:
# 0.08133224587104161

# %% [markdown]
# ### Question 2
#
# What percentage of tokens is 'whale'or 'Whale'?
#
# *This function should return a float.*

# %%
def answer_two():
    
    dist = FreqDist(text1)
    return (dist['whale'] + dist['Whale'])*100/example_one()

answer_two()
# Out:
# 0.4658312028483147

# %%
dist = FreqDist(text1)
dist
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
dist['whale'] + dist['Whale']
# Out:
# 1188

# %% [markdown]
# ### Question 3
#
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?
#
# *This function should return a list of 20 tuples where each tuple is of the form `(token, frequency)`. The list should be sorted in descending order of frequency.*

# %%
def answer_three():
    
    dist = FreqDist(text1)
    return dist.most_common(20)

answer_three()
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632)]

# %%
dist.most_common(20)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632)]

# %% [markdown]
# ### Question 4
#
# What tokens have a length of greater than 5 and frequency of more than 150?
#
# *This function should return an alphabetically sorted list of the tokens that match the above constraints. To sort your list, use `sorted()`*

# %%
def answer_four():
    dist = FreqDist(text1)
    freqwords = [w for w in dist.keys() if len(w) > 5 and dist[w] > 150]
    return sorted(freqwords)

answer_four()
# Out:
# ['Captain',
#  'Pequod',
#  'Queequeg',
#  'Starbuck',
#  'almost',
#  'before',
#  'himself',
#  'little',
#  'seemed',
#  'should',
#  'though',
#  'through',
#  'whales',
#  'without']

# %%
freqwords = [w for w in dist.keys() if len(w) > 5 and dist[w] > 150]

# %%
sorted(freqwords)
# Out:
# ['Captain',
#  'Pequod',
#  'Queequeg',
#  'Starbuck',
#  'almost',
#  'before',
#  'himself',
#  'little',
#  'seemed',
#  'should',
#  'though',
#  'through',
#  'whales',
#  'without']

# %%
dist['through']
# Out:
# 227

# %% [markdown]
# ### Question 5
#
# Find the longest word in text1 and that word's length.
#
# *This function should return a tuple `(longest_word, length)`.*

# %%
def answer_five():
    dist = FreqDist(text1)
    frame = pd.DataFrame(dist.most_common(), columns=["token", "frequency"])
    frame['len'] = frame.token.str.len()
    return (frame.loc[frame[frame['len'] == frame.len.max()].index[0], 'token'], frame.len.max())

answer_five()
# Out:
# ('uninterpenetratingly', 20)

# %%
frame = pd.DataFrame(dist.most_common(),
                                        columns=["token", "frequency"])

# %%
frame['len'] = frame.token.str.len()

# %%
frame
# Out:
#            token  frequency  len
# 0              ,      18713    1
# 1            the      13721    3
# 2              .       6862    1
# 3             of       6536    2
# 4            and       6024    3
# ...          ...        ...  ...
# 19312  dirgelike          1    9
# 19313   padlocks          1    8
# 19314   sheathed          1    8
# 19315  retracing          1    9
# 19316     orphan          1    6
#
# [19317 rows x 3 columns]

# %%
frame.loc[frame[frame['len'] == frame.len.max()].index[0], 'token']
# Out:
# 'uninterpenetratingly'

# %% [markdown]
# ### Question 6
#
# What unique words have a frequency of more than 2000? What is their frequency?
#
# "Hint:  you may want to use `isalpha()` to check if the token is a word and not punctuation."
#
# *This function should return a list of tuples of the form `(frequency, word)` sorted in descending order of frequency.*

# %%
dist = FreqDist(text1)
dist
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
dist3 = FreqDist(moby_tokens)
dist3
# Out:
# FreqDist({',': 19204, 'the': 13715, '.': 7306, 'of': 6513, 'and': 6010, 'a': 4545, 'to': 4515, ';': 4173, 'in': 3908, 'that': 2978, ...})

# %%
#dist.most_common()

# %%
frame = pd.DataFrame(dist.most_common(), columns=["token", "frequency"])

# %%
word_and_not_punct = frame[frame.token.str.isalpha()]

# %%
word_and_not_punct
# Out:
#            token  frequency
# 1            the      13721
# 3             of       6536
# 4            and       6024
# 5              a       4569
# 6             to       4542
# ...          ...        ...
# 19312  dirgelike          1
# 19313   padlocks          1
# 19314   sheathed          1
# 19315  retracing          1
# 19316     orphan          1
#
# [19032 rows x 2 columns]

# %%
answer = word_and_not_punct[word_and_not_punct['frequency'] > 2000][['frequency', 'token']]

# %%
res = answer.to_records(index=False)
result = list(res)
result
# Out:
# [(13721, 'the'),
#  (6536, 'of'),
#  (6024, 'and'),
#  (4569, 'a'),
#  (4542, 'to'),
#  (3916, 'in'),
#  (2982, 'that'),
#  (2459, 'his'),
#  (2209, 'it'),
#  (2124, 'I')]

# %%
def answer_six():
    
    dist = FreqDist(text1)
    frame = pd.DataFrame(dist.most_common(), columns=["token", "frequency"])
    word_and_not_punct = frame[frame.token.str.isalpha()]
    answer = word_and_not_punct[word_and_not_punct['frequency'] > 2000][['frequency', 'token']]
    
    res = answer.to_records(index=False)
    result = list(res)
    return result

answer_six()
# Out:
# [(13721, 'the'),
#  (6536, 'of'),
#  (6024, 'and'),
#  (4569, 'a'),
#  (4542, 'to'),
#  (3916, 'in'),
#  (2982, 'that'),
#  (2459, 'his'),
#  (2209, 'it'),
#  (2124, 'I')]

# %% [markdown]
# ### Question 7
#
# What is the average number of tokens per sentence?
#
# *This function should return a float.*

# %%
sent = nltk.sent_tokenize(moby_raw)
sent[0]
# Out:
# '[Moby Dick by Herman Melville 1851]\n\n\nETYMOLOGY.'

# %%
word_len_insent = [len(nltk.word_tokenize(i)) for i in sent]

# %%
sum(word_len_insent)/len(word_len_insent)
# Out:
# 25.88591149005278

# %%
def answer_seven():
    sent = nltk.sent_tokenize(moby_raw)
    word_len_insent = [len(nltk.word_tokenize(i)) for i in sent]
    return sum(word_len_insent)/len(word_len_insent)

answer_seven()
# Out:
# 25.88591149005278

# %% [markdown]
# ### Question 8
#
# What are the 5 most frequent parts of speech in this text? What is their frequency?
#
# *This function should return a list of tuples of the form `(part_of_speech, frequency)` sorted in descending order of frequency.*

# %%
word = nltk.word_tokenize('The weather is really good today!')

# %%
nltk.pos_tag()
# Out:
# [('The', 'DT'),
#  ('weather', 'NN'),
#  ('is', 'VBZ'),
#  ('really', 'RB'),
#  ('good', 'JJ'),
#  ('today', 'NN'),
#  ('!', '.')]

# %%
tags = nltk.pos_tag(word_and_not_punct.token)
tags
# Out:
# [('the', 'DT'),
#  ('of', 'IN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('to', 'TO'),
#  ('in', 'IN'),
#  ('that', 'DT'),
#  ('his', 'PRP$'),
#  ('it', 'PRP'),
#  ('I', 'PRP'),
#  ('is', 'VBZ'),
#  ('with', 'IN'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('as', 'IN'),
#  ('all', 'DT'),
#  ('for', 'IN'),
#  ('this', 'DT'),
#  ('at', 'IN'),
#  ('not', 'RB'),
#  ('by', 'IN'),
#  ('but', 'CC'),
#  ('him', 'PRP'),
#  ('from', 'IN'),
#  ('be', 'VB'),
#  ('on', 'IN'),
#  ('so', 'IN'),
#  ('one', 'CD'),
#  ('you', 'PRP'),
#  ('whale', 'VBP'),
#  ('had', 'VBD'),
#  ('have', 'VBP'),
#  ('there', 'RB'),
#  ('But', 'CC'),
#  ('or', 'CC'),
#  ('were', 'VBD'),
#  ('now', 'RB'),
#  ('which', 'WDT'),
#  ('me', 'PRP'),
#  ('their', 'PRP$'),
#  ('The', 'DT'),
#  ('are', 'VBP'),
#  ('they', 'PRP'),
#  ('an', 'DT'),
#  ('some', 'DT'),
#  ('then', 'RB'),
#  ('my', 'PRP$'),
#  ('like', 'IN'),
#  ('when', 'WRB'),
#  ('upon', 'NN'),
#  ('into', 'IN'),
#  ('out', 'RP'),
#  ('more', 'RBR'),
#  ('up', 'RB'),
# ...

# %%
frequen_speech = FreqDist([tag for (word, tag) in tags])
frequen_speech
# Out:
# FreqDist({'NN': 3947, 'JJ': 2953, 'NNP': 2952, 'NNS': 2419, 'VBG': 1402, 'VBD': 1329, 'RB': 1139, 'VBP': 715, 'VBN': 509, 'VBZ': 419, ...})

# %%
frequen_speech.most_common(5)
# Out:
# [('NN', 3947), ('JJ', 2953), ('NNP', 2952), ('NNS', 2419), ('VBG', 1402)]

# %%
res = speech.head(5).to_records(index=False)
result = list(res)
result
# Out:
# [('NN', 32727), ('IN', 28662), ('DT', 25879), (',', 19204), ('JJ', 17613)]

# %%
def answer_eight():
    import collections
    pos_token = nltk.pos_tag(text1)
    pos_counts = collections.Counter((subl[1] for subl in pos_token))
    return pos_counts.most_common(5)

answer_eight()
# Out:
# [('NN', 32727), ('IN', 28662), ('DT', 25879), (',', 19204), ('JJ', 17613)]

# %% [markdown]
# ## Part 2 - Spelling Recommender
#
# For this part of the assignment you will create three different spelling recommenders, that each take a list of misspelled words and recommends a correctly spelled word for every word in the list.
#
# For every misspelled word, the recommender should find find the word in `correct_spellings` that has the shortest distance*, and starts with the same letter as the misspelled word, and return that word as a recommendation.
#
# *Each of the three different recommenders will use a different distance measure (outlined below).
#
# Each of the recommenders should provide recommendations for the three default words provided: `['cormulent', 'incendenece', 'validrate']`.

# %%
from nltk.corpus import words

correct_spellings = words.words()

# %%
correct_spellings[37000:]
# Out:
# ['clammy',
#  'clammyweed',
#  'clamor',
#  'clamorer',
#  'clamorist',
#  'clamorous',
#  'clamorously',
#  'clamorousness',
#  'clamorsome',
#  'clamp',
#  'clamper',
#  'clamshell',
#  'clamworm',
#  'clan',
#  'clancular',
#  'clancularly',
#  'clandestine',
#  'clandestinely',
#  'clandestineness',
#  'clandestinity',
#  'clanfellow',
#  'clang',
#  'clangful',
#  'clangingly',
#  'clangor',
#  'clangorous',
#  'clangorously',
#  'Clangula',
#  'clanjamfray',
#  'clanjamfrey',
#  'clanjamfrie',
#  'clanjamphrey',
#  'clank',
#  'clankety',
#  'clanking',
#  'clankingly',
#  'clankingness',
#  'clankless',
#  'clanless',
#  'clanned',
#  'clanning',
#  'clannishly',
#  'clannishness',
#  'clansfolk',
#  'clanship',
#  'clansman',
#  'clansmanship',
#  'clanswoman',
#  'Claosaurus',
#  'clap',
#  'clapboard',
#  'clapbread',
#  'clapmatch',
#  'clapnet',
#  'clapped',
#  'clapper',
#  'clapperclaw',
#  'clapperclawer',
#  'clapperdudgeon',
#  'clappermaclaw',
#  'clapping',
# ...

# %% [markdown]
# ### Question 9
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the trigrams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams
from nltk.metrics.distance  import edit_distance
def answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    res = []
    for entry in entries:
        temp = [(jaccard_distance(set(ngrams(entry, 3)), set(ngrams(w, 3))),w) for w in correct_spellings if w[0]==entry[0]]
        #print(temp)
        res += [sorted(temp, key = lambda val:val[0])[0][1]]
    return res
    
answer_nine()
# Out:
# ['corpulent', 'indecence', 'validate']

# %%
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams
from nltk.metrics.distance  import edit_distance

# %%
entries=['cormulent', 'incendenece', 'validrate']

# %%
res = []
for entry in entries:
    temp = [(jaccard_distance(set(ngrams(entry, 3)), set(ngrams(w, 3))),w) for w in correct_spellings if w[0]==entry[0]]
    #print(temp)
    res += [sorted(temp, key = lambda val:val[0])[0][1]]

# %%
res
# Out:
# ['corpulent', 'indecence', 'validate']

# %%
set(ngrams('cormulent',2))
# Out:
# {('c', 'o'),
#  ('e', 'n'),
#  ('l', 'e'),
#  ('m', 'u'),
#  ('n', 't'),
#  ('o', 'r'),
#  ('r', 'm'),
#  ('u', 'l')}

# %%
set(ngrams('cnemapophysis', 2))
# Out:
# {('a', 'p'),
#  ('c', 'n'),
#  ('e', 'm'),
#  ('h', 'y'),
#  ('i', 's'),
#  ('m', 'a'),
#  ('n', 'e'),
#  ('o', 'p'),
#  ('p', 'h'),
#  ('p', 'o'),
#  ('s', 'i'),
#  ('y', 's')}

# %%
jaccard_distance(set(ngrams('cormulent', 2)), set(ngrams('cnemapophysis', 2)))#пересение таплов делится на обьединение таплов
# Out:
# 1.0

# %%
from nltk import ngrams
sentence = input("Enter the sentence: ")
n = int(input("Enter the value of n: "))
n_grams = ngrams(sentence.split(), n)
for grams in n_grams:
    print(grams)
# Out:
# Enter the sentence: We are so happy, because we are together
# Enter the value of n: 2
# ('We', 'are')
# ('are', 'so')
# ('so', 'happy,')
# ('happy,', 'because')
# ('because', 'we')
# ('we', 'are')
# ('are', 'together')

# %%
ngrams
# Out:
# <function nltk.util.ngrams(sequence, n, **kwargs)>

# %% [markdown]
# ### Question 10
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the 4-grams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams
from nltk.metrics.distance  import edit_distance
def answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    res = []
    for entry in entries:
        temp = [(jaccard_distance(set(ngrams(entry, 4)), set(ngrams(w, 4))),w) for w in correct_spellings if w[0]==entry[0]]
        #print(temp)
        res += [sorted(temp, key = lambda val:val[0])[0][1]]
    return res
    
answer_nine()

# %% [markdown]
# ### Question 11
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Edit distance on the two words with transpositions.](https://en.wikipedia.org/wiki/Damerau%E2%80%93Levenshtein_distance)**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %% [markdown]
# определяемая как минимальное количество операций вставки, удаления, замены и транспозиции (перестановки двух соседних символов), необходимых для перевода одной строки в другую.

# %%
def answer_eleven(entries=['cormulent', 'incendenece', 'validrate']):
    res = []
    for entry in entries:
        temp = [(edit_distance(entry, w),w) for w in correct_spellings if w[0]==entry[0]]
        res += [sorted(temp, key = lambda val:val[0])[0][1]]
    return res
    
answer_eleven()
# Out:
# ['corpulent', 'intendence', 'validate']

# %%
for entry in entries:
    temp = [(edit_distance(entry, w),w) for w in correct_spellings if w[0]==entry[0]]
    res += [sorted(temp, key = lambda val:val[0])[0][1])]
# Out:
# corpulent
# intendence
# validate

# %%
def answer_six_2():
    import operator
    from nltk.book import FreqDist
    token_dict  =FreqDist(moby_tokens)
    res_lis = {}
    for w in token_dict.keys() :
        if w.isalpha() and token_dict[w] > 2000 :
            res_lis[w] = token_dict[w]    
    sorted_res_list = sorted(res_lis.items(), key=operator.itemgetter(1))
    sorted_res_list.reverse()
    result = [(f,w) for w,f in sorted_res_list]
    return result
answer_six()
# Out:
# [(13715, 'the'),
#  (6513, 'of'),
#  (6010, 'and'),
#  (4545, 'a'),
#  (4515, 'to'),
#  (3908, 'in'),
#  (2978, 'that'),
#  (2459, 'his'),
#  (2196, 'it'),
#  (2113, 'I')]

# %%
answer_six() == answer_six_2()
# Out:
# True

# %%
def answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    from nltk.metrics.distance import (
    jaccard_distance,
    )
    from nltk.util import ngrams
    spellings_series = pd.Series(correct_spellings)
    correct = []
    for entry in entries :
        spellings = spellings_series[spellings_series.str.startswith(entry[0])]
        distances = ((jaccard_distance(set(ngrams(entry, 3)),set(ngrams(word, 3))), word) for word in spellings)
        closet = min(distances)
        correct.append(closet[1])
        
    return correct

# %%
answer_nine()
# Out:
# ['corpulent', 'indecence', 'validate']

# %%
def answer_ten(entries=['cormulent', 'incendenece', 'validrate']):
    from nltk.metrics.distance import (
    jaccard_distance,
    )
    from nltk.util import ngrams
    spellings_series = pd.Series(correct_spellings)
    correct = []
    for entry in entries :
        spellings = spellings_series[spellings_series.str.startswith(entry[0])]
        distances = ((jaccard_distance(set(ngrams(entry, 4)),set(ngrams(word, 4))), word) for word in spellings)
        closet = min(distances)
        correct.append(closet[1])
        
    return correct
    
answer_ten()
# Out:
# ['cormus', 'incendiary', 'valid']
